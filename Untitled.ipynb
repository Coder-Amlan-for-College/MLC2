# %%
import pandas as pd
data = {"ID":[1,2,3,4,5,6,7],
        "Name":["A","B","C","D","E","F","G"],
       "Age":[10,11,12,13,14,15,16],
       "City":["C1","C1","C1","C1","C1","C1","C1"],
       "Blood Grp":["A+","B+","O+","A-","B-","O-","AB+"],
       }
df = pd.DataFrame(data)

# %%
df.shape
# Out:
# (7, 5)

# %%
df
# Out:
#    ID Name  Age City Blood Grp
# 0   1    A   10   C1        A+
# 1   2    B   11   C1        B+
# 2   3    C   12   C1        O+
# 3   4    D   13   C1        A-
# 4   5    E   14   C1        B-
# 5   6    F   15   C1        O-
# 6   7    G   16   C1       AB+

# %%
df.to_csv("data.csv",index=False)

# %%
df2 = pd.read_csv("data.csv")

# %%
df2.head()
# Out:
#    ID Name  Age City Blood Grp
# 0   1    A   10   C1        A+
# 1   2    B   11   C1        B+
# 2   3    C   12   C1        O+
# 3   4    D   13   C1        A-
# 4   5    E   14   C1        B-

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris(as_frame=True)

# %%
x=iris[:,:-1]
y=iris[:,-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 x=iris[:,:-1]
#       2 y=iris[:,-1]
#
# File /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/_bunch.py:34, in Bunch.__getitem__(self, key)
#      33 def __getitem__(self, key):
# ---> 34     if key in self.__dict__.get("_deprecated_key_to_warnings", {}):
#      35         warnings.warn(
#      36             self._deprecated_key_to_warnings[key],
#      37             FutureWarning,
#      38         )
#      39     return super().__getitem__(key)
#
# TypeError: unhashable type: 'slice'
